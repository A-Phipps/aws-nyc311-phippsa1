# %%
import pandas as pd
import boto3
import numpy as np

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
# Test 2: Connect to S3
s3 = boto3.client('s3')
response = s3.list_buckets()
bucket_count = len(response['Buckets'])

print(f"Connected to S3")
print(f"Found {bucket_count} S3 buckets")

# Print your buckets (to identify your modeling data bucket)
for bucket in response['Buckets']:
    print(f"  - {bucket['Name']}")
# Out:
# Connected to S3
# Found 1 S3 buckets
#   - cmse492-phippsa1-nyc311-799024661739-us-east-1-an

# %%
import pandas as pd
import boto3
from io import StringIO

s3 = boto3.client('s3')
bucket_name = 'cmse492-phippsa1-nyc311-799024661739-us-east-1-an' # replace with your bucket name (make sure you have the account regional suffix)
file_name = 'raw/modeling/modeling_data.csv' # make sure to include the path if it's in a folder, e.g. 'modeling/modeling_data.csv'

obj = s3.get_object(Bucket=bucket_name, Key=file_name)
data = obj['Body'].read().decode('utf-8')
df = pd.read_csv(StringIO(data))

# %%
# First few rows
print("First few rows:")
print(df.head())

# Data types and missing values
print("\n" + "="*50)
print("Data types and missing values:")
print(df.info())
# Out:
# First few rows:
#   agency    borough               problem  incident_zip  day_of_week  \
# 0   NYPD      BRONX    Noise - Commercial       10473.0            2
# 1    DPR   BROOKLYN          Damaged Tree       11213.0            2
# 2    DEP  MANHATTAN                 Noise       10028.0            2
# 3    HPD   BROOKLYN              ELECTRIC       11226.0            2
# 4    HPD   BROOKLYN  UNSANITARY CONDITION       11226.0            2
#
#    hour_of_day problem_category  resolved_quickly
# 0           11            noise                 1
# 1           11            other                 1
# 2           11            noise                 1
# 3           11          housing                 0
# 4           11          housing                 0
#
# ...
# Data types and missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173870 entries, 0 to 173869
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ...

# %%
print("Summary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#         incident_zip    day_of_week    hour_of_day  resolved_quickly
# count  172102.000000  173870.000000  173870.000000     173870.000000
# mean    10838.989564       3.898533      13.005797          0.840617
# std       528.749576       1.990198       6.034836          0.366034
# min     10000.000000       1.000000       0.000000          0.000000
# 25%     10452.000000       2.000000       9.000000          1.000000
# 50%     11205.000000       4.000000      13.000000          1.000000
# 75%     11235.000000       6.000000      18.000000          1.000000
# max     11697.000000       7.000000      23.000000          1.000000
